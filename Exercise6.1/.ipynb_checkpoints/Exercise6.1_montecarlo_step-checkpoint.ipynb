# %% [markdown]
# Questo codice mostra all'interno di una signola simulazione l'andamento delle osservabili di interesse al crescere del numero di blocchi utilizzati per stimarle. Tali osservabili dovrebbero convergere verso il valore teorico predetto per la temperatura a cui si è eseguita la simulazione (si veda il jupyter notebook Exercise6.1)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

#fig=plt.figure(figsize=(15, 10))

num_lines = sum(1 for line in open('./code/risultati/DataBlockingOsservable1.dat'))
num_lines = int(num_lines / 2)

x, f, error = np.loadtxt("./code/risultati/DataBlockingOsservable1.dat", usecols=(0,1,2), delimiter='	', unpack='true', max_rows=num_lines)
plt.errorbar(x,f,yerr=error, errorevery=1, fmt='c.-', elinewidth=1, capsize=1, ms=3, label="Gibbs")

x, f, error = np.loadtxt("./code/risultati/DataBlockingOsservable1.dat", usecols=(0,1,2), delimiter='	', unpack='true', skiprows=num_lines)
plt.errorbar(x,f,yerr=error, errorevery=1, fmt='r.-', elinewidth=1, capsize=1, ms=3, label="Metropolis")

plt.xlabel('Number of block')
plt.ylabel('$U/N$')
plt.title('Internal Energy')
plt.legend()
plt.grid(True)

plt.show()

# %%
x, f, error = np.loadtxt("./code/risultati/DataBlockingOsservable2.dat", usecols=(0,1,2), delimiter='	', unpack='true', max_rows=num_lines)
plt.errorbar(x,f,yerr=error, errorevery=1, fmt='c.-', elinewidth=1, capsize=1, ms=3, label="Gibbs")

x, f, error = np.loadtxt("./code/risultati/DataBlockingOsservable2.dat", usecols=(0,1,2), delimiter='	', unpack='true', skiprows=num_lines)
plt.errorbar(x,f,yerr=error, errorevery=1, fmt='r.-', elinewidth=1, capsize=1, ms=3, label="Metropolis")

plt.xlabel('Number of block')
plt.ylabel('$C/N$')
plt.title('Heat Capacity')
plt.legend()
plt.grid(True)

plt.show()

# %%
x, f, error = np.loadtxt("./code/risultati/DataBlockingOsservable3.dat", usecols=(0,1,2), delimiter='	', unpack='true', max_rows=num_lines)
plt.errorbar(x,f,yerr=error, errorevery=1, fmt='c.-', elinewidth=1, capsize=1, ms=3, label="Gibbs")

x, f, error = np.loadtxt("./code/risultati/DataBlockingOsservable3.dat", usecols=(0,1,2), delimiter='	', unpack='true', skiprows=num_lines)
plt.errorbar(x,f,yerr=error, errorevery=1, fmt='r.-', elinewidth=1, capsize=1, ms=3, label="Metropolis")

plt.xlabel('Number of block')
plt.ylabel('$\chi$')
plt.title('Magnetic Susceptibility')
plt.legend()
plt.grid(True)

plt.show()

# %%
x, f, error = np.loadtxt("./code/risultati/DataBlockingOsservable4.dat", usecols=(0,1,2), delimiter='	', unpack='true', max_rows=num_lines)
plt.errorbar(x,f,yerr=error, errorevery=1, fmt='c.-', elinewidth=1, capsize=1, ms=3, label="Gibbs")

x, f, error = np.loadtxt("./code/risultati/DataBlockingOsservable4.dat", usecols=(0,1,2), delimiter='	', unpack='true', skiprows=num_lines)
plt.errorbar(x,f,yerr=error, errorevery=1, fmt='r.-', elinewidth=1, capsize=1, ms=3, label="Metropolis")

plt.xlabel('Number of block')
plt.ylabel('$M$')
plt.title('Magnetization')
plt.legend()
plt.grid(True)

plt.show()
